# %%
# %matplotlib nbagg

# %%
import pandas as pd

# %%
Efield = pd.read_csv('Edata.csv')
Hfield = pd.read_csv('Hdata.csv')

# %%
# from matplotlib import pyplot as plt
# from celluloid import Camera

# fig = plt.figure()
# camera = Camera(fig)
# for i in range(3702):
#     plt.plot(field.iloc[i, :], color = 'blue')
#     #plt.legend([f'step {i}'])
#     camera.snap()
# animation = camera.animate(interval = 1)

# %%
device_start_pos = 15
device_end_post = 116
N= 131

# %%
from matplotlib import pyplot as plt
from celluloid import Camera

fig = plt.figure()
camera = Camera(fig)
for i in range(Efield.shape[0]):
    plt.plot(Efield.iloc[i, :], color = 'red')
    plt.plot(Hfield.iloc[i, :], color = 'blue')

    plt.hlines(0,device_start_pos , device_end_post, colors='black', linestyles='solid', linewidth = 4,
              label = 'device')
    #plt.legend()
    camera.snap()
animation = camera.animate(interval = 5, repeat = False)

#import networkx as nx
#from matplotlib.animation import FuncAnimation, PillowWriter 
#animation.save('device.gif', writer='imagemagick', fps=300)
#animation.save('air.gif', writer='imagemagick')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#animation.save('animation.gif', writer='PillowWriter', fps=2)

# %%
# import matplotlib
# matplotlib.matplotlib_fname()
